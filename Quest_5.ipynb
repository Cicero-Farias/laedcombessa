# %% [markdown]
# <a href="https://colab.research.google.com/github/Cicero-Farias/laedcombessa/blob/Lista-1/Quest_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Itens *a* e *b*, respectivamente.

# %%
def alguem_e_dobro_nao_ordenada(V):
    seen = set()
    for x in V:
        if 2 * x in seen or (x % 2 == 0 and (x // 2) in seen):
            if 2 * x in seen:
                return (x, 2 * x)
            else:
                return (x // 2, x)
        seen.add(x)
    return None

V = [9, 42, 21, 14, 25, 3, 19, 33, 45, 6]
print(alguem_e_dobro_nao_ordenada(V))

# %%
def alguem_e_dobro_ordenada(V):
    i, j = 0, 0
    n = len(V)
    while i < n and j < n:
        if i == j:
            j += 1
            continue
        if V[j] == 2 * V[i]:
            return (V[i], V[j])
        if V[j] < 2 * V[i]:
            j += 1
        else:
            i += 1
    return None

V_sorted = sorted([9, 42, 21, 14, 25, 3, 19, 33, 45, 6])
print(V_sorted, alguem_e_dobro_ordenada(V_sorted))
