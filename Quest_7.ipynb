# %% [markdown]
# <a href="https://colab.research.google.com/github/Cicero-Farias/laedcombessa/blob/Lista-1/Quest_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def contar_inversoes(V):
    def merge_count(left, right):
        i = j = 0
        merged = []
        inv = 0
        while i < len(left) and j < len(right):
            if left[i] <= right[j]:
                merged.append(left[i])
                i += 1
            else:
                merged.append(right[j])
                j += 1
                inv += len(left) - i
        if i < len(left):
            merged.extend(left[i:])
        if j < len(right):
            merged.extend(right[j:])
        return merged, inv

    def sort_count(arr):
        n = len(arr)
        if n <= 1:
            return arr, 0
        mid = n // 2
        left, inv_left = sort_count(arr[:mid])
        right, inv_right = sort_count(arr[mid:])
        merged, inv_merge = merge_count(left, right)
        return merged, inv_left + inv_right + inv_merge

    _, inversoes = sort_count(list(V))
    return inversoes

V = [9, 2, 7, 7, 2, 2, 1, 7, 7, 9]
print(contar_inversoes(V))
